# %% [markdown]
# <a href="https://colab.research.google.com/github/Georgehub-star/IntroLabs/blob/master/2ndLectPyF_DrJavierLopez.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# Given 2 strings needle and haystack, Return [index] of 1st occurance of needle in haystack
def find_the_needle(haystack,needle):
    return haystack.find(needle)
    # First Occurance of a needle in this case index[0] sad

# %%
find_the_needle("sadbutsad","sad")
# Out:
# 0

# %%
find_the_needle("butsad","sad")
# Out:
# 3

# %%
find_the_needle("butsad","but")
# Out:
# 0

# %%
find_the_needle("butsad","ut")
# Out:
# 1

# %%
find_the_needle("butsad","t")
# Out:
# 2

# %%
# Given 2 strings needle and haystack, Return [index] of 1st occurance of "needle" (leeto)  in haystack(leetcode")
# OR -1 if "needle" which is "leeto" is not part of haystack.

find_the_needle("leetcode","leeto")
# Out:
# -1

# %%
find_the_needle("leetcode","leet")
# Out:
# 0

# %%
find_the_needle("leetcode","code")
# Out:
# 4

# %%
find_the_needle("leetcode","de")
# Out:
# 6

# %%
find_the_needle("leetcode","ed")
# Out:
# -1

# %%
# class Solution(object):
def strStr(haystack, needle):
        #nl, ml = len(needle), len(haystack)
        ml = len(haystack)
        nl = len(needle)
        if nl == 0: # if length of the needle is "0" or empty string
            return 0
        if ml == 0: # if length of the haystack is "0" or empty string
            return 0
        if ml < nl: # length of haystack is shorter then impossible to find it
        # This means var1(ml) or (leetcode) is not equal to var2(leetc) print -1
            return -1
# above if the length of the haystack is "SHORTER" than the needle,
# IT'S  impossible to find the needle in the haystack so retruns -1

        for i in range(ml - nl + 1):
            if haystack[i:i+nl] == needle:
                return i
        return -1
# Taking slice"i" "[i:i+nl"] == needle, equal to the length of the needle
# return "i" - first index of the needle
# Otherwise - needle not equal to haystack
# return -1

# %%
find_the_needle("leetcode","leet")
# Out:
# 0

# %%
find_the_needle("leetcode","ode")
# Out:
# 5

# %%
find_the_needle("leetcode","de")
# Out:
# 6

# %%
find_the_needle("leetcode","leeto")
# Out:
# -1

# %%
def find_the_needle(haystack,needle):
    ml, nl = len(haystack), len(needle)
    if nl == 0:
        return 0
    if ml < nl:
        return -1
        for i in range(ml - nl +1):
            if haystack[i:i+nl]==needle:
                return i
            return -1

# %%
find_the_needle("leetcode","leet")

# %%
def find_the_needle(haystack,needle):
    for i in range(len(haystack)):
        print(haystack[i:i+len(needle)])
        #if haystack[i:i+len(needle)]==needle:
    return i
    return -1

# %%
find_the_needle("leetcode","leet")
# Out:
# leet
# eetc
# etco
# tcod
# code
# ode
# de
# e
# 7

# %%
def find_the_needle(haystack,needle):
    for i in range(len(haystack)):
        #print(haystack[i:i+len(needle)])
        if haystack[i:i+len(needle)]==needle:
          return i
    return -1

# %%
find_the_needle("leetcode","leet")
# Out:
# 0

# %%
find_the_needle("leetcode","code")
# Out:
# 4

# %%
def find_the_needle(haystack,needle):
    for i in range(len(haystack)):
        #print(haystack[i:i+len(needle)])
        if haystack[i:i+len(needle)]==needle:
          print(haystack[i:i+len(needle)])
          return i
    return -1

# %%
find_the_needle("leetcode","code")
# Out:
# code
# 4

# %%
first_tuple = (1,2,3,3.0,"string",(1,2,3))
first_tuple.count(3)
first_tuple.index(3)
first_tuple.index("string")
first_tuple.index((1,2,3))
# Out:
# 5

# %%
first_tuple.index(2)
# Out:
# 1

# %%
first_tuple.index(3)
# Out:
# 2

# %%
first_tuple.index("string")
# Out:
# 5

# %%
first_tuple.index((1,2,3))
# Out:
# 6

# %%
first_tuple[4]=5 # can not be modified or immutable or can not be changed
# 'tuple' object does not support item assignment
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# /tmp/ipykernel_20873/1882774785.py in <cell line: 0>()
# ----> 1 first_tuple[4]=5
#
# TypeError: 'tuple' object does not support item assignment

# %%
first_tuple.append(5) # can not be modified or immutable or can not be changed

# %%
first_tuple[1:4]
# Out:
# (2, 3, 3.0)

# %%
# PACKING
second_tuple = 1,2,3,3.0,"string",(1,2,3) # STORES multiple VARIABLES, int, string, floats

# %%
second_tuple
# Out:
# (1, 2, 3, 3.0, 'string', (1, 2, 3))

# %%
name = "Deepak"
age = 23
city = "dallas"

# %%
student = name, age, city

# %%
student
# Out:
# ('Deepak', 23, 'dallas')

# %%
# UNPACKING

# %%
name, age, city = student

# %%
name
# Out:
# 'Deepak'

# %%
age
# Out:
# 23

# %%
city
# Out:
# 'dallas'

# %%
# IMPORTant check below # Tuples does not presver meaning to store age=dallas, city=23

# %%
name, age, city = student

# %%
name, city, age = student

# %%
name
# Out:
# 'Deepak'

# %%
age
# Out:
# 'dallas'

# %%
city
# Out:
# 23

# %%
name, age = student # Tuples "unpack" All or Nothing # Check len(3) or how many values
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# /tmp/ipykernel_20873/1802264397.py in <cell line: 0>()
# ----> 1 name, age = student
#
# ValueError: too many values to unpack (expected 2)

# %%
# Realtime use cases: Tuples powerful when you want to return more than one value function

# %%
name, age, city, degree = student
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# /tmp/ipykernel_20873/416134511.py in <cell line: 0>()
# ----> 1 name, age, city, degree = student
#
# ValueError: not enough values to unpack (expected 4, got 3)

# %%
# Creating a tuple
my_tuple = (1,2,3,"Hello",3.14)

# Accessing elements of a tuple
print(my_tuple[0])  # Output: 1
print(my_tuple[3])  # Output: "Hello"

#Slicing a tuple
print(my_tuple[1:4])  # Output: (2, 3, 'Hello')

#length of tuple
print(len(my_tuple))  # Output: 5

# looping through a tuple
for item in my_tuple:
    print(item)
# Out:
# 1
# Hello
# (2, 3, 'Hello')
# 5
# 1
# 2
# 3
# Hello
# 3.14

# %%
# looping through a tuple
for item in my_tuple:
    print(item)
# Out:
# 1
# 2
# 3
# Hello
# 3.14

# %%
# Nested tuple
nested_tuple = ((1,2,3),("Hello",3.14))
print(nested_tuple[0])
print(nested_tuple[1])
print(nested_tuple[0][1])
# Out:
# (1, 2, 3)
# ('Hello', 3.14)
# 2

# %%
# Nested tuple
nested_tuple = ((1,2), (3,4), (5,6))
print(nested_tuple[0][1])
# Out:
# 2

# %%
# Unpacking a tuple
x, y = (10,20)
print(x)
print(y)
# Out:
# 10
# 20

# %%
# Tuples can RETURN Values
# Using Tuples to return multiple values

def divide_and_remainder(a, b):
    quotient = a // b
    remainder = a % b
    return quotient, remainder

# %%
result = divide_and_remainder(10, 3)
print(result)
# Out:
# (3, 1)

# %%
result = divide_and_remainder(10, 5)
print(result)
# Out:
# (2, 0)

# %%
def divide_and_remainder(a, b):
    quotient = a // b
    remainder = a % b
    return quotient, remainder

    quotient, remainder = divide_and_remainder(10, 3)

# %%
quotient, remainder = divide_and_remainder(10, 3)
quotient
# Out:
# 3

# %%
quotient, remainder = divide_and_remainder(10, 3)
remainder
# Out:
# 1
